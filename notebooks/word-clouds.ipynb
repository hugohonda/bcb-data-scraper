# %%
sws = stopwords.words('portuguese')

data = json.load(open('../output/1998-2018-copom-records.json'))

string_text = ''
for content in data:
  if content['year'] == 1999:
    for topic in content['topics']:
      string_text = topic['content']
break
print(string_text)
# Out:
#  Os indicadores de demanda agregada mostram recuperacao moderada nos meses de outubro e novembro com elevacao tenue nos niveis de consumo e investimento. O volume de credito continua mostrando evolucao favoravel em cenario de reducao dos niveis de inadimplencia e de melhoria nas condicoes de credito praticadas no comercio. Ate outubro o faturamento real do comercio varejista em cinco regioes metropolitanas acumula contracao de 4,63%. Contudo esse resultado reverte-se em estabilidade ao se excluir o desempenho das concessionarias de automoveis. No mesmo periodo o faturamento em bens de consumo apresenta estabilidade enquanto o do comercio automotivo reduziu-se em 29,75% seguido pela diminuicao de 5,47% em material de construcao. O credito ao setor privado mantem a trajetoria ascendente iniciada no segundo trimestre de 1999. A taxa de inadimplencia do sistema financeiro privado em outubro 4,6% manteve tendencia decrescente enquanto no sistema financeiro publico a reducao observada foi 
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

months = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']
months = [x.lower() for x in months]
sws.extend(months)
sws.append('copom')
wordcloud = WordCloud(stopwords=sws,
                      background_color='white',
                      max_font_size=50, 
                      max_words=300).generate(string_text)
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
